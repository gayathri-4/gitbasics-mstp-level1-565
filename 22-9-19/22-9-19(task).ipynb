# %% [markdown]
# ### 1. reverse string

# %%
t=input()
v=input()
print(v,t,sep=" ")
# Out:
# lekireddy
# gayathri
# gayathri lekireddy

# %% [markdown]
# ### 2.accepting file and print extension

# %%
s=input()
e=s.split('.')
d=e[1]
print(d)
# Out:
# hello.py
# py

# %% [markdown]
# ### 3.print value of n+nn+nnn

# %%
n=int(input())
print(n+n*n+n*n*n)
# Out:
# 5
# 155

# %% [markdown]
# ### 4.string sep by space and swap letter

# %%
a=input()
b=input()
a1=b[0:2]+a[2:]
b1=a[0:2]+b[2:]
print(a1+" "+b1)
# Out:
# abc
# xyz
# xyc abz

# %% [markdown]
# ### 5.upper and lower cases

# %%
s=input()
print(s.swapcase())
# Out:
# Mstp Level2 Python
# mSTP lEVEL2 pYTHON

# %% [markdown]
# ### 6.print n characters in lowercase

# %%
n=input()
l=int(input())
print(n[0:l].lower()+n[l:])
# Out:
# QWERTYUIOPLKHG
# 5
# qwertYUIOPLKHG
